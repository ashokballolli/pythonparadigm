# %%
import pandas as pd # for data wrangling and analysis

# %%
import os

# %%
dir(os)
# Out:
# ['CLD_CONTINUED',
#  'CLD_DUMPED',
#  'CLD_EXITED',
#  'CLD_TRAPPED',
#  'DirEntry',
#  'EX_CANTCREAT',
#  'EX_CONFIG',
#  'EX_DATAERR',
#  'EX_IOERR',
#  'EX_NOHOST',
#  'EX_NOINPUT',
#  'EX_NOPERM',
#  'EX_NOUSER',
#  'EX_OK',
#  'EX_OSERR',
#  'EX_OSFILE',
#  'EX_PROTOCOL',
#  'EX_SOFTWARE',
#  'EX_TEMPFAIL',
#  'EX_UNAVAILABLE',
#  'EX_USAGE',
#  'F_LOCK',
#  'F_OK',
#  'F_TEST',
#  'F_TLOCK',
#  'F_ULOCK',
#  'MutableMapping',
#  'NGROUPS_MAX',
#  'O_ACCMODE',
#  'O_APPEND',
#  'O_ASYNC',
#  'O_CLOEXEC',
#  'O_CREAT',
#  'O_DIRECTORY',
#  'O_DSYNC',
#  'O_EXCL',
#  'O_EXLOCK',
#  'O_NDELAY',
#  'O_NOCTTY',
#  'O_NOFOLLOW',
#  'O_NONBLOCK',
#  'O_RDONLY',
#  'O_RDWR',
#  'O_SHLOCK',
#  'O_SYNC',
#  'O_TRUNC',
#  'O_WRONLY',
#  'PRIO_PGRP',
#  'PRIO_PROCESS',
#  'PRIO_USER',
#  'P_ALL',
#  'P_NOWAIT',
#  'P_NOWAITO',
#  'P_PGID',
#  'P_PID',
#  'P_WAIT',
#  'PathLike',
#  'RTLD_GLOBAL',
#  'RTLD_LAZY',
#  'RTLD_LOCAL',
#  'RTLD_NODELETE',
#  'RTLD_NOLOAD',
#  'RTLD_NOW',
# ...

# %%
os.listdir()
# Out:
# ['.DS_Store',
#  'pandas_tut01.ipynb',
#  'corona_dataset_kaggle',
#  '.ipynb_checkpoints']

# %%
df_xlsx = pd.read_excel('corona_dataset_kaggle/pokemon_data.xlsx')
df_xlsx.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df_txt = pd.read_csv('corona_dataset_kaggle/pokemon_data.txt', delimiter='\t')
df_txt.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df = pd.read_csv('corona_dataset_kaggle/IndividualDetails.csv')

# %%
df.head(5)
# Out:
#    id government_id diagnosed_date  age gender             detected_city  \
# 0   0      KL-TS-P1     30/01/2020   20      F                  Thrissur
# 1   1      KL-AL-P1     02/02/2020  NaN    NaN                 Alappuzha
# 2   2      KL-KS-P1     03/02/2020  NaN    NaN                 Kasaragod
# 3   3         DL-P1     02/03/2020   45      M  East Delhi (Mayur Vihar)
# 4   4         TS-P1     02/03/2020   24      M                 Hyderabad
#
#   detected_district detected_state nationality current_status  \
# 0          Thrissur         Kerala       India      Recovered
# 1         Alappuzha         Kerala       India      Recovered
# 2         Kasaragod         Kerala       India      Recovered
# 3        East Delhi          Delhi       India      Recovered
# 4         Hyderabad      Telangana       India      Recovered
#
#   status_change_date                                              notes
# 0         14/02/2020                               Travelled from Wuhan
# ...

# %%
df.describe()
# Out:
#                  id
# count  28182.000000
# mean   14091.344759
# std     8135.814132
# min        0.000000
# 25%     7046.250000
# 50%    14091.500000
# 75%    21136.750000
# max    28182.000000

# %%
df_columns = df.columns
df_columns
# Out:
# Index(['id', 'government_id', 'diagnosed_date', 'age', 'gender',
#        'detected_city', 'detected_district', 'detected_state', 'nationality',
#        'current_status', 'status_change_date', 'notes'],
#       dtype='object')

# %%
df.dtypes
# Out:
# id                     int64
# government_id         object
# diagnosed_date        object
# age                   object
# gender                object
# detected_city         object
# detected_district     object
# detected_state        object
# nationality           object
# current_status        object
# status_change_date    object
# notes                 object
# dtype: object

# %%
df['age'].describe()
# Out:
# count     2346
# unique      92
# top         35
# freq        89
# Name: age, dtype: object

# %%
df['detected_city'][0:5]
# Out:
# 0                    Thrissur
# 1                   Alappuzha
# 2                   Kasaragod
# 3    East Delhi (Mayur Vihar)
# 4                   Hyderabad
# Name: detected_city, dtype: object

# %%
df[['diagnosed_date', 'detected_city', 'detected_state']][0:5]
# Out:
#   diagnosed_date             detected_city detected_state
# 0     30/01/2020                  Thrissur         Kerala
# 1     02/02/2020                 Alappuzha         Kerala
# 2     03/02/2020                 Kasaragod         Kerala
# 3     02/03/2020  East Delhi (Mayur Vihar)          Delhi
# 4     02/03/2020                 Hyderabad      Telangana

# %%
df.iloc[1] # row from index 1
# Out:
# id                                       1
# government_id                     KL-AL-P1
# diagnosed_date                  02/02/2020
# age                                    NaN
# gender                                 NaN
# detected_city                    Alappuzha
# detected_district                Alappuzha
# detected_state                      Kerala
# nationality                          India
# current_status                   Recovered
# status_change_date              14/02/2020
# notes                 Travelled from Wuhan
# Name: 1, dtype: object

# %%
df.iloc[0:4] # first 4 records , 4th index is not included
# Out:
#    id government_id diagnosed_date  age gender             detected_city  \
# 0   0      KL-TS-P1     30/01/2020   20      F                  Thrissur
# 1   1      KL-AL-P1     02/02/2020  NaN    NaN                 Alappuzha
# 2   2      KL-KS-P1     03/02/2020  NaN    NaN                 Kasaragod
# 3   3         DL-P1     02/03/2020   45      M  East Delhi (Mayur Vihar)
#
#   detected_district detected_state nationality current_status  \
# 0          Thrissur         Kerala       India      Recovered
# 1         Alappuzha         Kerala       India      Recovered
# 2         Kasaragod         Kerala       India      Recovered
# 3        East Delhi          Delhi       India      Recovered
#
#   status_change_date                          notes
# 0         14/02/2020           Travelled from Wuhan
# 1         14/02/2020           Travelled from Wuhan
# 2         14/02/2020           Travelled from Wuhan
# 3         15/03/2020  Travelled from Austria, Italy

# %%
df.iloc[1, 5] # value at a particular cell
# Out:
# 'Alappuzha'

# %%
# iterating through rows

# for index, row in df.iterrows():
#     print(index, row['detected_city'], row['current_status'])

# %%
df['age'].astype('int', errors='ignore')
# Out:
# 0         20
# 1        NaN
# 2        NaN
# 3         45
# 4         24
#         ...
# 28177    NaN
# 28178    NaN
# 28179    NaN
# 28180    NaN
# 28181    NaN
# Name: age, Length: 28182, dtype: object

# %%
# loc : using which can identiy the columns based on the text, filter on conditions
df.loc[df['detected_state'] == 'Delhi'].head(5)
# Out:
#     id government_id diagnosed_date  age gender             detected_city  \
# 3    3         DL-P1     02/03/2020   45      M  East Delhi (Mayur Vihar)
# 28  28         DL-P2     05/03/2020   27      M                 Janakpuri
# 30  30         DL-P3     06/03/2020  NaN    NaN               Uttam Nagar
# 39  39         DL-P4     09/03/2020   25      F                 Tri Nagar
# 63  63         DL-P5     11/03/2020   46      M                 Janakpuri
#
#    detected_district detected_state nationality current_status  \
# 3         East Delhi          Delhi       India      Recovered
# 28  South West Delhi          Delhi       India   Hospitalized
# 30        West Delhi          Delhi       India      Recovered
# 39       North Delhi          Delhi       India   Hospitalized
# 63  South West Delhi          Delhi       India   Hospitalized
#
#    status_change_date                                        notes
# 3          15/03/2020                Travelled from Austria, Italy
# ...

# %%
# df[df['age'] == 'NaN'] # This doesn't work because NaN isn't equal to anything, including NaN
df = df[pd.notnull(df['age'])]

# %%
df = df[~df['age'].str.contains('-')]

# %%
df['age'] = df['age'].astype('float')

# %%
df.head(5)
# Out:
#    id government_id diagnosed_date   age gender             detected_city  \
# 0   0      KL-TS-P1     30/01/2020  20.0      F                  Thrissur
# 3   3         DL-P1     02/03/2020  45.0      M  East Delhi (Mayur Vihar)
# 4   4         TS-P1     02/03/2020  24.0      M                 Hyderabad
# 5   5           NaN     03/03/2020  69.0      M                    Jaipur
# 6   6           NaN     04/03/2020  55.0    NaN                  Gurugram
#
#   detected_district detected_state nationality current_status  \
# 0          Thrissur         Kerala       India      Recovered
# 3        East Delhi          Delhi       India      Recovered
# 4         Hyderabad      Telangana       India      Recovered
# 5          Italians      Rajasthan       Italy      Recovered
# 6          Italians        Haryana       Italy      Recovered
#
#   status_change_date                                              notes
# 0         14/02/2020                               Travelled from Wuhan
# ...

# %%
df.dtypes
# Out:
# id                      int64
# government_id          object
# diagnosed_date         object
# age                   float64
# gender                 object
# detected_city          object
# detected_district      object
# detected_state         object
# nationality            object
# current_status         object
# status_change_date     object
# notes                  object
# dtype: object

# %%
df.loc[df['age'] < 5].describe()
# Out:
#                  id        age
# count     31.000000  31.000000
# mean    9998.709677   2.103226
# std     9206.042317   1.130924
# min       42.000000   0.300000
# 25%      724.000000   1.000000
# 50%     8892.000000   2.000000
# 75%    18921.000000   3.000000
# max    24949.000000   4.000000

# %%
# Sorting / Describing

# %%
df.head(3)
# Out:
#    id government_id diagnosed_date   age gender             detected_city  \
# 0   0      KL-TS-P1     30/01/2020  20.0      F                  Thrissur
# 3   3         DL-P1     02/03/2020  45.0      M  East Delhi (Mayur Vihar)
# 4   4         TS-P1     02/03/2020  24.0      M                 Hyderabad
#
#   detected_district detected_state nationality current_status  \
# 0          Thrissur         Kerala       India      Recovered
# 3        East Delhi          Delhi       India      Recovered
# 4         Hyderabad      Telangana       India      Recovered
#
#   status_change_date                                              notes
# 0         14/02/2020                               Travelled from Wuhan
# 3         15/03/2020                      Travelled from Austria, Italy
# 4         02/03/2020  Travelled from Dubai to Bangalore on 20th Feb,...

# %%
df.describe()
# Out:
#                  id          age
# count   2342.000000  2342.000000
# mean    9633.391973    38.488557
# std     9338.985214    17.265748
# min        0.000000     0.300000
# 25%     1386.500000    26.000000
# 50%     5371.500000    36.000000
# 75%    19120.750000    50.000000
# max    27948.000000    98.000000

# %%
df.sort_values('detected_state', ascending=False).head(5)
# Out:
#       id government_id diagnosed_date   age gender detected_city  \
# 859  859           NaN     27/03/2020  11.0      M           NaN
# 960  960           NaN     28/03/2020  56.0      F           NaN
# 198  198           NaN     20/03/2020  22.0      M     Beleghata
# 258  258           NaN     21/03/2020  23.0      F         Habra
# 326  326         WB-P4     21/03/2020  57.0      M       Dum Dum
#
#      detected_district detected_state nationality current_status  \
# 859              Nadia    West Bengal       India   Hospitalized
# 960    Purba Medinipur    West Bengal       India   Hospitalized
# 198            Kolkata    West Bengal       India   Hospitalized
# 258  North 24 Parganas    West Bengal       India      Recovered
# 326            Kolkata    West Bengal       India       Deceased
#
#     status_change_date                                              notes
# 859         27/03/2020  Family, History of contact to a positive case ...
# ...

# %%
df.sort_values(['detected_state', 'age'], ascending=[True, False])
# Out:
#         id government_id diagnosed_date   age gender  \
# 850    850           NaN     27/03/2020  64.0    NaN
# 735    735         AN-P2     27/03/2020  53.0      M
# 849    849           NaN     27/03/2020  23.0    NaN
# 1725  1725        AP-P78     01/04/2020  80.0      M
# 4288  4288       AP-P262     05/04/2020  80.0      F
# ...    ...           ...            ...   ...    ...
# 392    392           NaN     22/03/2020  20.0      F
# 143    143           NaN     17/03/2020  18.0      M
# 859    859           NaN     27/03/2020  11.0      M
# 862    862           NaN     27/03/2020   6.0      F
# 863    863           NaN     27/03/2020   1.0      F
#
#                    detected_city         detected_district  \
# 850                          NaN             South Andaman
# 735                          NaN  North and Middle Andaman
# 849                          NaN             South Andaman
# 1725                         NaN             Y.S.R. Kadapa
# ...

# %%
df['dummy_total'] = df['id'] + df['age']

# %%
df.head()
# Out:
#    id government_id diagnosed_date   age gender             detected_city  \
# 0   0      KL-TS-P1     30/01/2020  20.0      F                  Thrissur
# 3   3         DL-P1     02/03/2020  45.0      M  East Delhi (Mayur Vihar)
# 4   4         TS-P1     02/03/2020  24.0      M                 Hyderabad
# 5   5           NaN     03/03/2020  69.0      M                    Jaipur
# 6   6           NaN     04/03/2020  55.0    NaN                  Gurugram
#
#   detected_district detected_state nationality current_status  \
# 0          Thrissur         Kerala       India      Recovered
# 3        East Delhi          Delhi       India      Recovered
# 4         Hyderabad      Telangana       India      Recovered
# 5          Italians      Rajasthan       Italy      Recovered
# 6          Italians        Haryana       Italy      Recovered
#
#   status_change_date                                              notes  \
# ...

# %%
df.drop(columns=['dummy_total'], inplace=True)

# %%
df.head(3)
# Out:
#    id government_id diagnosed_date   age gender             detected_city  \
# 0   0      KL-TS-P1     30/01/2020  20.0      F                  Thrissur
# 3   3         DL-P1     02/03/2020  45.0      M  East Delhi (Mayur Vihar)
# 4   4         TS-P1     02/03/2020  24.0      M                 Hyderabad
#
#   detected_district detected_state nationality current_status  \
# 0          Thrissur         Kerala       India      Recovered
# 3        East Delhi          Delhi       India      Recovered
# 4         Hyderabad      Telangana       India      Recovered
#
#   status_change_date                                              notes
# 0         14/02/2020                               Travelled from Wuhan
# 3         15/03/2020                      Travelled from Austria, Italy
# 4         02/03/2020  Travelled from Dubai to Bangalore on 20th Feb,...
