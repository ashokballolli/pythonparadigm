# %%
import os
os.listdir(".")
# Out:
# ['.DS_Store',
#  '__init__.py',
#  'workingWithPandas.ipynb',
#  '.ipynb_checkpoints',
#  'data',
#  'Pandas_dataframe.ipynb']

# %%
import pandas as pd

# %%
df = pd.read_csv("data/data.txt")

# %%
df
# Out:
#    1     3666 21st St  San Francisco          CA 94114  USA      Madeira   8
# 0  2   735 Dolores St  San Francisco          CA 94119  USA  Bready Shop  15
# 1  3      332 Hill St  San Francisco  California 94114  USA  Super River  25
# 2  4     3995 23rd St  San Francisco          CA 94114  USA   Ben's Shop  10
# 3  5  1056 Sanchez St  San Francisco        California  USA      Sanchez  12
# 4  6  551 Alvarado St  San Francisco          CA 94114  USA   Richvalley  20

# %%
df = pd.read_csv("data/data.txt", header = None)

# %%
df
# Out:
#    0                1              2                 3    4            5   6
# 0  1     3666 21st St  San Francisco          CA 94114  USA      Madeira   8
# 1  2   735 Dolores St  San Francisco          CA 94119  USA  Bready Shop  15
# 2  3      332 Hill St  San Francisco  California 94114  USA  Super River  25
# 3  4     3995 23rd St  San Francisco          CA 94114  USA   Ben's Shop  10
# 4  5  1056 Sanchez St  San Francisco        California  USA      Sanchez  12
# 5  6  551 Alvarado St  San Francisco          CA 94114  USA   Richvalley  20

# %%
df.columns = ["Id","Address","city","Zip","Country","Name","Employees"]

# %%
df
# Out:
#    Id          Address           city               Zip Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
# how to assign an index column

# %%
# df.set_index("Id") # its not inplace operation

# %%
df.set_index("Id", inplace = True, drop=False)

# %%
#  now if you assign index with another column then the previous column which was the index disaapears, because with the above type of assigning index will make column to only index, so you cn retain the column while assigning it as index by the following way

# %%
# df.set_index("Address", inplace = True)

# %%
df
# Out:
#     Id          Address           city               Zip Country         Name  \
# Id
# 1    1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3    3      332 Hill St  San Francisco  California 94114     USA  Super River
# 4    4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5    5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6    6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# Id
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
# Data manipulation

# %%
df["Zip"]
# Out:
# Id
# 1            CA 94114
# 2            CA 94119
# 3    California 94114
# 4            CA 94114
# 5          California
# 6            CA 94114
# Name: Zip, dtype: object

# %%
# label based indexing and position based indexing

# %%
df.loc["4":"6", "city":"Name"] # upperbound values are included
# Out:
#              city         Zip Country        Name
# Id
# 4   San Francisco    CA 94114     USA  Ben's Shop
# 5   San Francisco  California     USA     Sanchez
# 6   San Francisco    CA 94114     USA  Richvalley

# %%
df.loc["4":, :"city"]
# Out:
#     Id          Address           city
# Id
# 4    4     3995 23rd St  San Francisco
# 5    5  1056 Sanchez St  San Francisco
# 6    6  551 Alvarado St  San Francisco

# %%
df.loc[:, "Country"]
# Out:
# Id
# 1    USA
# 2    USA
# 3    USA
# 4    USA
# 5    USA
# 6    USA
# Name: Country, dtype: object

# %%
list(df.loc[: , "Country"])
# Out:
# ['USA', 'USA', 'USA', 'USA', 'USA', 'USA']

# %%
df
# Out:
#     Id          Address           city               Zip Country         Name  \
# Id
# 1    1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3    3      332 Hill St  San Francisco  California 94114     USA  Super River
# 4    4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5    5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6    6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# Id
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df.iloc[1:3, 3:5] # upperbound values are excluded
# Out:
#                  Zip Country
# Id
# 2           CA 94119     USA
# 3   California 94114     USA

# %%
# Deleting rows , columns, not inplace operator

# %%
df.drop("city", 1) # 1 means column 0 means row , here drop a column with name city
# Out:
#     Id          Address               Zip Country         Name  Employees
# Id
# 1    1     3666 21st St          CA 94114     USA      Madeira          8
# 2    2   735 Dolores St          CA 94119     USA  Bready Shop         15
# 3    3      332 Hill St  California 94114     USA  Super River         25
# 4    4     3995 23rd St          CA 94114     USA   Ben's Shop         10
# 5    5  1056 Sanchez St        California     USA      Sanchez         12
# 6    6  551 Alvarado St          CA 94114     USA   Richvalley         20

# %%
df
# Out:
#     Id          Address           city               Zip Country         Name  \
# Id
# 1    1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3    3      332 Hill St  San Francisco  California 94114     USA  Super River
# 4    4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5    5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6    6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# Id
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df.drop(3, 0)
# Out:
#     Id          Address           city         Zip Country         Name  \
# Id
# 1    1     3666 21st St  San Francisco    CA 94114     USA      Madeira
# 2    2   735 Dolores St  San Francisco    CA 94119     USA  Bready Shop
# 4    4     3995 23rd St  San Francisco    CA 94114     USA   Ben's Shop
# 5    5  1056 Sanchez St  San Francisco  California     USA      Sanchez
# 6    6  551 Alvarado St  San Francisco    CA 94114     USA   Richvalley
#
#     Employees
# Id
# 1           8
# 2          15
# 4          10
# 5          12
# 6          20

# %%
# drop takes the header or index value and column or row identifier and its not inplace operation unless you mention inplace = True

# %%
df.columns
# Out:
# Index([u'Id', u'Address', u'city', u'Zip', u'Country', u'Name', u'Employees'], dtype='object')

# %%
df.index
# Out:
# Int64Index([1, 2, 3, 4, 5, 6], dtype='int64', name=u'Id')

# %%
# how to add row or columns to dataframe

# %%
df["continent"] = ["Asia"]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-243-7e97fe8994a0> in <module>()
# ----> 1 df["continent"] = ["Asia"]
#
# /Users/a.ballolli/Library/Python/2.7/lib/python/site-packages/pandas/core/frame.pyc in __setitem__(self, key, value)
#    3368         else:
#    3369             # set column
# -> 3370             self._set_item(key, value)
#    3371
#    3372     def _setitem_slice(self, key, value):
#
# /Users/a.ballolli/Library/Python/2.7/lib/python/site-packages/pandas/core/frame.pyc in _set_item(self, key, value)
#    3443
#    3444         self._ensure_valid_index(value)
# -> 3445         value = self._sanitize_column(key, value)
#    3446         NDFrame._set_item(self, key, value)
#    3447
#
# /Users/a.ballolli/Library/Python/2.7/lib/python/site-packages/pandas/core/frame.pyc in _sanitize_column(self, key, value, broadcast)
#    3628
# ...

# %%
len(df.index)

# %%
df.shape
# Out:
# (6, 7)

# %%
# df["continent"] = ["Asia", "Asia", "Asia", "Asia", "Asia", "Asia", ] # works but its not a good way and affects when you have too many rows

# %%
df.shape[0]
# Out:
# 6

# %%
df.shape[0]*["Asia"]
# Out:
# ['Asia', 'Asia', 'Asia', 'Asia', 'Asia', 'Asia']

# %%
df["continent"] = df.shape[0]*["Asia"]

# %%
df
# Out:
#     Id          Address           city               Zip Country         Name  \
# Id
# 1    1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3    3      332 Hill St  San Francisco  California 94114     USA  Super River
# 4    4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5    5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6    6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees continent
# Id
# 1           8      Asia
# 2          15      Asia
# 3          25      Asia
# 4          10      Asia
# 5          12      Asia
# 6          20      Asia

# %%
# update / create new column by referring to the existing column

# %%
df["continent"] = df["Country"] + " - " + "Asia"

# %%
df
# Out:
#     Id          Address           city               Zip Country         Name  \
# Id
# 1    1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3    3      332 Hill St  San Francisco  California 94114     USA  Super River
# 4    4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5    5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6    6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees   continent
# Id
# 1           8  USA - Asia
# 2          15  USA - Asia
# 3          25  USA - Asia
# 4          10  USA - Asia
# 5          12  USA - Asia
# 6          20  USA - Asia

# %%
# adding row is bit tricky, transpose table, add column and transpose it back

# %%
df_t = df.T

# %%
df_t
# Out:
# Id                     1               2                 3              4  \
# Id                     1               2                 3              4
# Address     3666 21st St  735 Dolores St       332 Hill St   3995 23rd St
# city       San Francisco   San Francisco     San Francisco  San Francisco
# Zip             CA 94114        CA 94119  California 94114       CA 94114
# Country              USA             USA               USA            USA
# Name             Madeira     Bready Shop       Super River     Ben's Shop
# Employees              8              15                25             10
# continent     USA - Asia      USA - Asia        USA - Asia     USA - Asia
#
# Id                       5                6
# Id                       5                6
# Address    1056 Sanchez St  551 Alvarado St
# city         San Francisco    San Francisco
# Zip             California         CA 94114
# Country                USA              USA
# ...

# %%
df_t[7] = [7, "my add", "my city", "my zip", "my country", "my name", "my emp", "my cont"]

# %%
df_t
# Out:
# Id                     1               2                 3              4  \
# Id                     1               2                 3              4
# Address     3666 21st St  735 Dolores St       332 Hill St   3995 23rd St
# city       San Francisco   San Francisco     San Francisco  San Francisco
# Zip             CA 94114        CA 94119  California 94114       CA 94114
# Country              USA             USA               USA            USA
# Name             Madeira     Bready Shop       Super River     Ben's Shop
# Employees              8              15                25             10
# continent     USA - Asia      USA - Asia        USA - Asia     USA - Asia
#
# Id                       5                6           7
# Id                       5                6           7
# Address    1056 Sanchez St  551 Alvarado St      my add
# city         San Francisco    San Francisco     my city
# Zip             California         CA 94114      my zip
# ...

# %%
df = df_t.T

# %%
df
# Out:
#    Id          Address           city               Zip     Country  \
# Id
# 1   1     3666 21st St  San Francisco          CA 94114         USA
# 2   2   735 Dolores St  San Francisco          CA 94119         USA
# 3   3      332 Hill St  San Francisco  California 94114         USA
# 4   4     3995 23rd St  San Francisco          CA 94114         USA
# 5   5  1056 Sanchez St  San Francisco        California         USA
# 6   6  551 Alvarado St  San Francisco          CA 94114         USA
# 7   7           my add        my city            my zip  my country
#
#            Name Employees   continent
# Id
# 1       Madeira         8  USA - Asia
# 2   Bready Shop        15  USA - Asia
# 3   Super River        25  USA - Asia
# 4    Ben's Shop        10  USA - Asia
# 5       Sanchez        12  USA - Asia
# 6    Richvalley        20  USA - Asia
# 7       my name    my emp     my cont
